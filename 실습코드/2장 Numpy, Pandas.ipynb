# %%
import numpy as np
import pandas as pd

data = ['spring', 'summer', 'autumn', 'winter']
print(data)
np1 = np.array(data)
print(np1)
season = pd.Series(data)
print(season)
print(type(data))
print(type(np1))
print(type(season))
# Out:
# ['spring', 'summer', 'autumn', 'winter']
# ['spring' 'summer' 'autumn' 'winter']
# 0    spring
# 1    summer
# 2    autumn
# 3    winter
# dtype: str
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'pandas.Series'>
