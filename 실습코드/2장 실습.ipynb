# %%
import pandas as pd

table = pd.DataFrame([[-0.1, 0.0, -0.1, -0.2], [1.8, 2.0, 1.6, 1.6], [6.4, 6.8, 5.8, 5.9],
                      [12.3, 12.9, 11.5, 11.5], [17.9, 18.5, 17.1, 17.1], [22.2, 22.8, 21.6, 21.5]]) #리스트 형식
table1 = pd.DataFrame({'전북' : [-0.1, 1.8, 6.4, 12.3, 17.9, 22.2],
          '전주' : [0.0, 2.0, 6.8, 12.9, 18.5, 22.8],
          '군산' : [-0.1, 1.6, 5.8, 11.5, 17.1, 21.6],
          '부안' : [-0.2, 1.6, 5.9, 11.5, 17.1, 21.5]}) #딕셔너리 형식
table.index = ["1월", "2월", "3월", "4월", "5월", "6월"]
table.columns = ["전북", "전주", "군산", "부안"]

#1
print(table)
print(table1)

#2
print(table.iloc[2, 1])

#3
print(table.iloc[3, 3])

#4
print(table.loc["1월", "군산"])

#5
print(table.loc["6월" , "전북"])
# Out:
#       전북    전주    군산    부안
# 1월  -0.1   0.0  -0.1  -0.2
# 2월   1.8   2.0   1.6   1.6
# 3월   6.4   6.8   5.8   5.9
# 4월  12.3  12.9  11.5  11.5
# 5월  17.9  18.5  17.1  17.1
# 6월  22.2  22.8  21.6  21.5
#      전북    전주    군산    부안
# 0  -0.1   0.0  -0.1  -0.2
# 1   1.8   2.0   1.6   1.6
# 2   6.4   6.8   5.8   5.9
# 3  12.3  12.9  11.5  11.5
# 4  17.9  18.5  17.1  17.1
# 5  22.2  22.8  21.6  21.5
# 6.8
# 11.5
# -0.1
# 22.2
