# %%
import pandas as pd

df = pd.read_csv('iris.csv')
print(df)
df.head(10)

print(df['Species'].unique())
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
import pandas as pd

df = pd.read_csv('iris.csv')
df3 = df.copy()

# print(df3)
# df3.iloc[1, 2] = 5.5
# print(df3)
# df3.loc[3, 'Petal_Length'] = 10
# print(df3)

# print(df)

# print(df3.Petal_Length.to_list())
# df3.loc[df.Petal_Length > 6.5, 'Petal_Length'] *= 100
# print(df3.Petal_Length.to_list())

# #코드 4-8
# new_idx = df3.shape[0]
# df3.loc[new_idx] = [1.1, 4.5, 3.4, 2.2, 'setosa']
# print(df3.tail())

# new_row = pd.DataFrame([[1.1, 2.2, 3.3, 4.4, 'virginica']], columns=df3.columns)

# print(new_row)
# df3 = pd.concat([df3.iloc[:10], new_row, df3.iloc[10:]], ignore_index = True)
# print(df3)
# print(df3.iloc[8:13, :])


new_col = df3.Petal_Length * 10
df3['new_col'] = new_col
print(df3)

new_col2 = df3.Petal_Length * 100
df4 = df.copy()
df4.insert(loc = 2, column = 'new_col2', value = new_col2)
print(df4)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species  new_col
# 0             5.1          3.5           1.4          0.2     setosa     14.0
# 1             4.9          3.0           1.4          0.2     setosa     14.0
# 2             4.7          3.2           1.3          0.2     setosa     13.0
# 3             4.6          3.1           1.5          0.2     setosa     15.0
# 4             5.0          3.6           1.4          0.2     setosa     14.0
# ..            ...          ...           ...          ...        ...      ...
# 145           6.7          3.0           5.2          2.3  virginica     52.0
# 146           6.3          2.5           5.0          1.9  virginica     50.0
# 147           6.5          3.0           5.2          2.0  virginica     52.0
# 148           6.2          3.4           5.4          2.3  virginica     54.0
# 149           5.9          3.0           5.1          1.8  virginica     51.0
#
# [150 rows x 6 columns]
#      Sepal_Length  Sepal_Width  new_col2  Petal_Length  Petal_Width    Species
# 0             5.1          3.5     140.0           1.4          0.2     setosa
# 1             4.9          3.0     140.0           1.4          0.2     setosa
# 2             4.7          3.2     130.0           1.3          0.2     setosa
# 3             4.6          3.1     150.0           1.5          0.2     setosa
# 4             5.0          3.6     140.0           1.4          0.2     setosa
# ..            ...          ...       ...           ...          ...        ...
# 145           6.7          3.0     520.0           5.2          2.3  virginica
# 146           6.3          2.5     500.0           5.0          1.9  virginica
# 147           6.5          3.0     520.0           5.2          2.0  virginica
# 148           6.2          3.4     540.0           5.4          2.3  virginica
# 149           5.9          3.0     510.0           5.1          1.8  virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# # 연습문제

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('titanic')
#1
print(df)

#2
print(df.columns)

#3
print(df.head(10))

#4
print(df['class'].unique())

#5
print(df.iloc[2, 4])

#6
print(df.loc[:4, ['pclass', 'sex', 'age', 'alive']])

#7
print(df.loc[df.age >= 60, ['sex', 'age', 'alive']])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False
# ['Third', 'First', 'Second']
# Categories (3, str): ['First', 'Second', 'Third']
# 0
#    pclass     sex   age alive
# 0       3    male  22.0    no
# 1       1  female  38.0   yes
# 2       3  female  26.0   yes
# 3       1  female  35.0   yes
# 4       3    male  35.0    no
#         sex   age alive
# 33     male  66.0    no
# 54     male  65.0    no
# 96     male  71.0    no
# 116    male  70.5    no
# 170    male  61.0    no
# 252    male  62.0    no
# 275  female  63.0   yes
# 280    male  65.0    no
# 326    male  61.0    no
# 366  female  60.0   yes
# 438    male  64.0    no
# 456    male  65.0    no
# 483  female  63.0   yes
# 493    male  71.0    no
# 545    male  64.0    no
# 555    male  62.0    no
# 570    male  62.0   yes
# 587    male  60.0   yes
# 625    male  61.0    no
# 630    male  80.0   yes
# 672    male  70.0    no
# 684    male  60.0    no
# 694    male  60.0    no
# 745    male  70.0    no
# 829  female  62.0   yes
# 851    male  74.0    no

# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('titanic')

# #8
# print(df.loc[(df.age < 10 ) & (df.sex == "female"), ['age', 'alive']])

# #9
# print(df.loc[(df.alive == "yes") & (df.sex == "male"), 'age'].mean())

# #10
# print(df.loc[(df.alive == 'yes'), 'alive'].count() / df.alive.count())
# # print(df.loc[(df.alive == 'yes'), 'alive'].count() / len(df))

# #11
# print(df.loc[(df.alive == 'yes') & (df.age == df.age.min()), ['sex', 'age']])

#12
# print(df.loc[(df.alive == "yes") & (df.pclass == 1), 'alive'].count())

# #13
# print(df.loc[(df.pclass == 1), 'pclass'].count() - df.loc[(df.pclass == 2), 'pclass'].count())

# #14
# df1 = df.loc[(df.alive == 'yes') & (df.pclass == 3), ['sex', 'age']]
# print(df1.loc[df1.age == df1.age.max()])

#15
df2 = df[['pclass', 'sex', 'age', 'alive']].copy()
print(df2)

#16
# df2['age_class'] = ''
# df2.loc[df2.age < 40, 'age_class'] = "Low"
# df2.loc[df2.age >= 40, 'age_class'] = "High"

# print(df2.head(20))

# #17

# df2.age + 10
# print(df2.age)

#18

df2.dropna(inplace = True)
print((df2.age + 10).mean())

#19
print(df2.loc[:, ~df2.columns.isin(['pclass'])])

#20
df2.to_csv('titanic2.csv')
# Out:
#      pclass     sex   age alive
# 0         3    male  22.0    no
# 1         1  female  38.0   yes
# 2         3  female  26.0   yes
# 3         1  female  35.0   yes
# 4         3    male  35.0    no
# ..      ...     ...   ...   ...
# 886       2    male  27.0    no
# 887       1  female  19.0   yes
# 888       3  female   NaN    no
# 889       1    male  26.0   yes
# 890       3    male  32.0    no
#
# [891 rows x 4 columns]
# 39.69911764705882
#         sex   age alive
# 0      male  22.0    no
# 1    female  38.0   yes
# 2    female  26.0   yes
# 3    female  35.0   yes
# 4      male  35.0    no
# ..      ...   ...   ...
# 885  female  39.0    no
# 886    male  27.0    no
# 887  female  19.0   yes
# 889    male  26.0   yes
# 890    male  32.0    no
#
# [714 rows x 3 columns]
