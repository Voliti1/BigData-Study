# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/mtcars.csv')

df.plot.scatter(x = 'wt', y = 'mpg')
plt.show()

df.plot.scatter(x = 'wt', y = 'mpg', s = 50, c = 'red', marker = 's')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/mtcars.csv")

vars = ['mpg', 'disp', 'drat', 'wt']
pd.plotting.scatter_matrix(df[vars])
plt.show()

# %% [markdown]
# mpg = Miles/gallon
# disp = 배기량
# drat = 후륜 차축 기어비
# wt = weight

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/iris.csv")

dict = {'setosa' : 'red', 'versicolor' : 'green', 'virginica' : 'blue'}
colors = list(dict[key] for key in df.Species)

# df.plot.scatter(x = 'Petal_Length', y = 'Petal_Width', s = 30, c = colors, marker = 'o')
# plt.show()

# df.plot.scatter(x = 'Petal_Length', y = 'Petal_Width', s = 30, c = colors, marker = 'o')
# plt.show()

fig, ax = plt.subplots()

for label, data in df.groupby('Species'):
    ax.scatter(x = data['Petal_Length'], y = data['Petal_Width'], s = 30,
               c = dict[label], marker = 'o', label = label)

ax.set_xlabel('Petal_Length')
ax.set_ylabel('Petal_Width')
ax.legend()
fig.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11064\353931636.py:24: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

beers = [5, 2, 9, 8, 3, 7, 3, 5, 3, 5]
bal = [0.1, 0.03, 0.19, 0.12, 0.04, 0.0095, 0.07, 0.06, 0.02, 0.05]

dict = {'beers': beers, 'bal' : bal}
df = pd.DataFrame(dict)
print(df)

df.plot.scatter(x = 'beers', y = 'bal', title = 'Beers~Blood Alcohol Level')
plt.show()

df.plot.scatter(x = 'beers', y = 'bal', title = 'Beers~Blood Alcohol Level')

m, b = np.polyfit(beers, bal, 1)
plt.plot(beers, m * np.array(beers) + b)
plt.show()

print(df['beers'].corr(df['bal']))
# Out:
# {'beers': [5, 2, 9, 8, 3, 7, 3, 5, 3, 5], 'bal': [0.1, 0.03, 0.19, 0.12, 0.04, 0.0095, 0.07, 0.06, 0.02, 0.05]}
#    beers     bal
# 0      5  0.1000
# 1      2  0.0300
# 2      9  0.1900
# 3      8  0.1200
# 4      3  0.0400
# 5      7  0.0095
# 6      3  0.0700
# 7      5  0.0600
# 8      3  0.0200
# 9      5  0.0500
# 0.6797024899347416

# %%
import pandas as pd

df = pd.read_csv("data/iris.csv")
df2 = df.loc[:, ~df.columns.isin(['Species'])]
print(df2, '\n')
print(df2.corr(), '\n')
print(df['Petal_Width'].corr(df['Petal_Length']))
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
#
#               Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# Sepal_Length      1.000000    -0.117570      0.871754     0.817941
# Sepal_Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal_Length      0.871754    -0.428440      1.000000     0.962865
# Petal_Width       0.817941    -0.366126      0.962865     1.000000
#
# 0.9628654314027961

# %%
import pandas as pd
import matplotlib.pyplot as plt

late = pd.Series([5, 8, 7, 9, 4, 6, 12, 13, 8, 6, 6, 4], index = list(range(1, 13)))
late.plot(title = 'Late student per month',
          xlabel = 'month',
          ylabel = 'frequency',
          linestyle = 'solid')
plt.show()

late.plot(title = 'Late student per month',
          xlabel = 'month',
          ylabel = 'frequency',
          marker = 'o')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

late1 = [5, 8, 7, 9, 4, 6, 12, 13, 8, 6, 6, 4]
late2 = [4, 6, 5, 8, 7, 8, 10, 11, 6, 5, 7, 3]

dict = {'class_1' : late1 , 'class_2' : late2}

late = pd.DataFrame(dict, index = list(range(1, 13)))
print(late)

late.plot(title = 'Late student per month',
          xlabel = 'month',
          ylabel = 'frequency',
          marker = 'o')

plt.legend(loc='upper right')
plt.show()
# Out:
#     class_1  class_2
# 1         5        4
# 2         8        6
# 3         7        5
# 4         9        8
# 5         4        7
# 6         6        8
# 7        12       10
# 8        13       11
# 9         8        6
# 10        6        5
# 11        6        7
# 12        4        3
