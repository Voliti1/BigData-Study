# %%
import pandas as pd
temp = pd.Series([-0.8, -0.1, 7.7, 13.8, 18.0, 22.4, 
                  25.9, 25.3, 21.0, 14.0, 9.6, -1.4])

temp.index = ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월']

# print(temp)

# print(len(temp))
# print(temp.size)
# print(temp.shape)
# print(temp.dtype)

# print(temp.iloc[2]) # 7.7
# print(temp.loc["3월"]) # 7.7
# print(temp.iloc[[3, 5, 7]]) #13.8, 22.4, 25.3
# print(temp.loc[['4월', '5월', '6월']]) #13.8, 18.0, 22.4

# print(temp.iloc[5:8]) #22.4, 25.9, 25.3
# print(temp.loc['6월':'9월']) #22.4, 25.9, 25.3, 21.0
# print(temp.iloc[:4]) #-0.8, -0.1, 7.7, 13.8
# print(temp.iloc[9:]) #14.0, 9.6, -1.4
# print(temp.iloc[:]) #전체

# print(temp.loc[temp >= 15])
# print(temp.loc[(temp > 15) & (temp < 25)])
# print(temp.loc[(temp < 5) | (temp >= 25)])

# march = temp.loc['3월']
# print(temp.loc[temp < march])

# print(temp.where(temp >= 15))
# print(temp.where(temp >= 15).dropna())

# print(temp.loc[temp >= 15])
# print(temp.loc[temp >= 15].index)

# print(temp)
# print(temp + 1)

# print(temp)
# print(2 * temp + 0.1)

# print(temp)
# print(2 * temp)

# print(temp)
# print(temp.loc[temp >= 15] + 1)

print(temp)
print(temp.sum())
print(temp.median())
print(temp.mean())
print(temp.max())
print(temp.min())
print(temp.std())
print(temp.var())
print(temp.abs())
print(temp.describe())
print(temp.value_counts())
# Out:
# 1월     -0.8
# 2월     -0.1
# 3월      7.7
# 4월     13.8
# 5월     18.0
# 6월     22.4
# 7월     25.9
# 8월     25.3
# 9월     21.0
# 10월    14.0
# 11월     9.6
# 12월    -1.4
# dtype: float64
# 155.39999999999998
# 13.9
# 12.949999999999998
# 25.9
# -1.4
# 10.026011624315478
# 100.52090909090909
# 1월      0.8
# 2월      0.1
# 3월      7.7
# 4월     13.8
# 5월     18.0
# 6월     22.4
# 7월     25.9
# 8월     25.3
# 9월     21.0
# 10월    14.0
# 11월     9.6
# 12월     1.4
# dtype: float64
# count    12.000000
# mean     12.950000
# std      10.026012
# min      -1.400000
# 25%       5.750000
# 50%      13.900000
# 75%      21.350000
# max      25.900000
# dtype: float64
# -0.8     1
# -0.1     1
#  7.7     1
#  13.8    1
#  18.0    1
#  22.4    1
#  25.9    1
#  25.3    1
#  21.0    1
#  14.0    1
#  9.6     1
# -1.4     1
# Name: count, dtype: int64

# %%
import pandas as pd

salary = pd.Series([20, 15, 18, 30])
score = pd.Series([75, 80, 90, 60], index = ['KOR', 'ENG', 'MATH', 'SOC'])

# print(salary, "\n")
# print(score, "\n")

# score.iloc[0] = 85
# print(score, "\n")
# score.loc['SOC'] = 65
# print(score, "\n")
# score.loc[['ENG' , 'MATH']] = [70, 80]
# print(score, "\n")

score.loc['PHY'] = 50 #맨 뒤에 추가
# print(score, "\n")

# #score.iloc[5] = 90

next_idx = salary.size
# salary.iloc[next_idx] = 33
salary.loc[next_idx] = 33
print(salary)

salary.loc[10] = 33
salary.loc[12] = 49
print(salary, "\n")
salary1 = salary.reset_index(drop=True, inplace=True)
print(salary, "\n")
print(salary1, "\n")

salary2 = pd.concat([salary, pd.Series([50])])
salary3 = pd.concat([salary, pd.Series([50])], ignore_index=True)
print(salary2, "\n")
print(salary3, "\n")

salary4 = pd.concat([salary3[:4], pd.Series([100]), salary3[4:]], ignore_index = True)
print(salary4, "\n")

print(score, "\n")
score.drop('PHY')
print(score, "\n")

score = score.drop('PHY')
print(score, "\n")

salary1 = salary.drop(1)
print(salary1)

salary2 = salary.drop([3, 4])
print(salary2)
# Out:
# 0    20
# 1    15
# 2    18
# 3    30
# 4    33
# dtype: int64
# 0     20
# 1     15
# 2     18
# 3     30
# 4     33
# 10    33
# 12    49
# dtype: int64
#
# 0    20
# 1    15
# 2    18
# 3    30
# 4    33
# 5    33
# 6    49
# dtype: int64
#
# None
#
# 0    20
# 1    15
# 2    18
# 3    30
# 4    33
# 5    33
# 6    49
# 0    50
# dtype: int64
#
# 0    20
# 1    15
# 2    18
# 3    30
# 4    33
# 5    33
# 6    49
# 7    50
# dtype: int64
#
# 0     20
# 1     15
# 2     18
# 3     30
# 4    100
# 5     33
# 6     33
# 7     49
# 8     50
# dtype: int64
#
# KOR     75
# ENG     80
# MATH    90
# SOC     60
# PHY     50
# dtype: int64
#
# KOR     75
# ENG     80
# MATH    90
# SOC     60
# PHY     50
# dtype: int64
#
# KOR     75
# ENG     80
# MATH    90
# SOC     60
# dtype: int64
#
# 0    20
# 2    18
# 3    30
# 4    33
# 5    33
# 6    49
# dtype: int64
# 0    20
# 1    15
# 2    18
# 5    33
# 6    49
# dtype: int64
